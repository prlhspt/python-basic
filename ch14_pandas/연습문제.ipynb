# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # 3. 각 학교의 총 학생수 마지막 열에 삽입하는 프로그램 작성

# %%
import pandas
df = pandas.read_csv('high_school_2019.csv')
df
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수
# 0          149         5       143
# 1          228         8       270
# ...

# %%
df2 = df.drop(df.columns[[0, 1]], axis='columns')

# %%
df2 = df2.sum(axis=1)

# %%
df2.astype(int)
# Out:
# 0       457
# 1       761
# 2       543
# 3       865
# 4       638
#        ...
# 2393    896
# 2394    451
# 2395    284
# 2396    298
# 2397    355
# Length: 2398, dtype: int32

# %%
df['총 학생수']=df2.astype(int)

# %%
df
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수  총 학생수
# 0          149         5       143    457
# 1          228         8       270    761
# ...

# %% [markdown]
# # 4. 학년별 총 학생수 막대 그래프로 시각화

# %%
# Matplotlib 사용과 한글 처리를 위한 Code
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False # minus 표시
mpl.rc('font', family = 'Malgun Gothic')
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["font.size"] = 14

# %%
df3 = df.drop(df.columns[[0, 1, 2, 4, 6, 8]], axis='columns')
df3 = df3.sum(axis=0)

# %%
df3
# Out:
#  1학년 학생수    463400
#  2학년 학생수    444714
#  3학년 학생수    500698
# dtype: int64

# %%
df3.plot.bar(rot=0)
plt.title("전국 고등학교 학년별 총 학생수")
plt.show()

# %% [markdown]
# # 5. 100세 이상 열 기준으로 내림차순 정렬후 실행결과 출력

# %%
import pandas
df = pandas.read_csv('population_age_2020.csv')
df
# Out:
#       지역      총인구수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 4     광주   1456121   125396   162728   207554   191432   244903   234048
# 5     대전   1473125   120476   151861   212143   199106   242381   243526
# 6     울산   1145710   103399   115623   147745   158271   190698   211255
# 7     세종    343788    47454    40574    36273    61442    65714    42907
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# ...

# %%
df2 = df.drop(df.columns[2:12], axis='columns')

# %%
df2 = df2.sort_values(by='100세 이상' ,ascending=False)

# %%
df2 = df2.reset_index(drop=True)
df2
# Out:
#       지역      총인구수  100세 이상
# 0     서울   9736962     6380
# 1    경기도  13265377     4010
# 2     부산   3410925     1807
# 3   경상북도   2658956      960
# 4     인천   2954955      908
# 5   충청남도   2120995      885
# 6   전라남도   1861894      822
# 7   전라북도   1815112      817
# 8    강원도   1539521      803
# 9   경상남도   3358828      739
# 10    대구   2432883      694
# 11  충청북도   1598599      541
# 12    광주   1456121      405
# 13    대전   1473125      339
# 14   제주도    670876      266
# 15    울산   1145710      160
# 16    세종    343788       55

# %%
df2 = df2[['지역', '100세 이상', '총인구수']]

# %%
df2
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 1    경기도     4010  13265377
# 2     부산     1807   3410925
# 3   경상북도      960   2658956
# 4     인천      908   2954955
# 5   충청남도      885   2120995
# 6   전라남도      822   1861894
# 7   전라북도      817   1815112
# 8    강원도      803   1539521
# 9   경상남도      739   3358828
# 10    대구      694   2432883
# 11  충청북도      541   1598599
# 12    광주      405   1456121
# 13    대전      339   1473125
# 14   제주도      266    670876
# 15    울산      160   1145710
# 16    세종       55    343788
